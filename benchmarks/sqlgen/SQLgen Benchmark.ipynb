# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Times New Roman"
plt.rcParams['axes.linewidth'] = 1
plt.rcParams.update({'font.size': 13})


# mpl.rcParams['mathtext.fontset'] = 'custom'
# mpl.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
# mpl.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
# mpl.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'

#mpl.rcParams['mathtext.fontset'] = 'cm'
#mpl.rcParams['font.family'] = 'Times New Roman'

# import matplotlib
# matplotlib.font_manager._rebuild()
import numpy as np

# %%
fig, ax = plt.subplots()
ax.plot([5.44, 10.88, 16.32, 21.76, 27.19], [1.273, 2.32, 3.423, 5.146, 6.012],  label="Spark RDD", ls='--', marker='s')
ax.plot([5.44, 10.88, 16.32, 21.76, 27.19], [1.095, 2.468, 3.957, 5.348, 5.639], label="DIABLO",    ls='-.', marker='o')
ax.plot([5.44, 10.88, 16.32, 21.76, 27.19], [1.256, 2.051, 2.619, 4.487, 5.324], label="SQLGen",    ls=':', marker='*')
ax.plot([5.44, 10.88, 16.32, 21.76, 27.19], [1.122, 1.519, 2.165, 3.185, 3.532], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_ylabel('Total Time (secs)')
ax.set_title('(A) Sum',y=-.27);
plt.savefig('sum.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([7.08, 14.16, 21.23, 28.31, 35.39], [23.455, 44.48, 79.91, 98.09, 165.923], label="Spark RDD", ls='--', marker='s')
ax.plot([7.08, 14.16, 21.23, 28.31, 35.39], [26.938, 55.7, 94.135, 125.18, 220.30], label="DIABLO", ls='-.', marker='o')
ax.plot([7.08, 14.16, 21.23, 28.31, 35.39], [9.649, 18.181, 30.06, 41.71, 74.29], label="SQLGen",  ls=':', marker='*')
ax.plot([7.08, 14.16, 21.23, 28.31, 35.39], [9.968, 18.938, 33.5, 39.992, 83.22], label="Spark SQL",  ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(C) GroupBy',y=-.27);
plt.savefig('group-by.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([2.29, 4.59, 6.88, 9.18, 11.47], [2.381, 5.498, 6.92, 9.283, 13.92], label="Spark RDD", ls='--', marker='s')
ax.plot([2.29, 4.59, 6.88, 9.18, 11.47], [2.86, 5.348, 8.32, 9.773, 13.613], label="DIABLO",ls='-.', marker='o')
ax.plot([2.29, 4.59, 6.88, 9.18, 11.47], [3.28, 5.78, 7.22, 9.422, 11.78], label="SQLGen", ls=':', marker='*')
ax.plot([2.29, 4.59, 6.88, 9.18, 11.47], [3.358, 5.88, 7.46, 8.9, 11.471], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(B) Word Count',y=-.27);
plt.savefig('word-count.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([0.04, 0.09], [29.552, 80], label="Spark RDD", ls='--', marker='s')
ax.plot([0.04, 0.09], [29.198, 83.08], label="DIABLO", ls='-.', marker='o')
ax.plot([0.04, 0.09, 2.07, 2.76, 3.46], [2.058, 3.82, 64.49, 93.73, 132.33], label="SQLGen", ls=':', marker='*')
ax.plot([0.04, 0.09, 2.07, 2.76, 3.46], [2.15, 3.68, 65.19, 97.3, 131.83], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(H) Matrix Multiplication',y=-.27);
plt.savefig('matrix-multiplication.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([3.39,  6.77, 10.16, 13.55, 16.93], [10.10, 19.57, 27.89, 34.46, 48.1], label="Spark RDD", ls='--', marker='s')
ax.plot([3.39,  6.77, 10.16, 13.55, 16.93], [9.13, 16.75, 23.6, 31.581, 40.13], label="DIABLO", ls='-.', marker='o')
ax.plot([3.39,  6.77, 10.16, 13.55, 16.93], [4.475, 7.86, 11.135, 13.49, 19.54], label="SQLGen",  ls=':', marker='*')
ax.plot([3.39,  6.77, 10.16, 13.55, 16.93], [4.043, 8.074, 11.883, 14.18, 20.368], label="Spark SQL",  ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_ylabel('Total Time (secs)')
ax.set_title('(E) Histogram',y=-.27);
plt.savefig('histogram.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([0.54,  1.09, 1.63, 2.18, 2.72], [9.98, 20.741, 37.38, 41.94, 74], label="Spark RDD", ls='--', marker='s')
ax.plot([0.54,  1.09, 1.63, 2.18, 2.72], [12.12, 24, 23.6, 52.507, 90.53], label="DIABLO", ls='-.', marker='o')
ax.plot([0.54,  1.09, 1.63, 2.18, 2.72], [2.73, 2.95, 3.77, 4.74, 5.45], label="SQLGen", ls=':', marker='*')
ax.plot([0.54,  1.09, 1.63, 2.18, 2.72], [2.03, 2.6, 3.7, 4.221, 4.82], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(D) GroupByJoin',y=-.27);
plt.savefig('group-by-join.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([2.12,  4.23, 6.34, 8.46, 10.59], [29.96, 75.93, 115.261, 197.21, 239.37], label="Spark RDD", ls='--', marker='s')
ax.plot([2.12,  4.23, 6.34, 8.46, 10.59], [44.29, 102.04, 202.57, 302.82, 350], label="DIABLO", ls='-.', marker='o')
ax.plot([2.12,  4.23, 6.34, 8.46, 10.59], [3.47, 6.10, 10.23, 12.63, 16.5], label="SQLGen", ls=':', marker='*')
ax.plot([2.12,  4.23, 6.34, 8.46, 10.59], [3.26, 5.76, 14.22, 12.95, 14.513], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(G) Matrix Addition',y=-.27);
plt.savefig('matrix-addition.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([0.05, 0.08, 0.11, 0.46, 0.52], [2.27, 3.68, 6.13, 221.9, 266.53], label="Spark RDD", ls='--', marker='s')
ax.plot([0.05, 0.08, 0.11], [49.06, 101.7, 176.8], label="DIABLO", ls='-.', marker='o')
ax.plot([0.05, 0.08, 0.11, 0.46, 0.52], [1.77, 1.86, 2.24, 25.73, 27.2], label="SQLGen", ls=':', marker='*')
ax.plot([0.05, 0.08, 0.11, 0.46, 0.52 ], [1.14, 2.2, 1.9, 24.96, 26.98], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(J) PCA',y=-.27);
plt.savefig('pca.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([4.3,  8.6, 12.9, 17.3, 21.6], [2.78, 5.09, 9.06, 10.01, 12.932], label="Spark RDD", ls='--', marker='s')
ax.plot([4.3,  8.6, 12.9, 17.3, 21.6], [13, 25.1, 41.834, 54.15, 62.22], label="DIABLO", ls='-.', marker='o')
ax.plot([4.3,  8.6, 12.9, 17.3, 21.6], [3.85, 5.867, 10.59, 10.41, 13.63], label="SQLGen", ls=':', marker='*')
ax.plot([4.3,  8.6, 12.9, 17.3, 21.6], [2.91, 5.836, 8.79, 10.29, 13.44], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_ylabel('Total Time (secs)')
ax.set_title('(I) Linear Regression',y=-.27);
plt.savefig('linear-regression.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([0.73, 7.26, 14.53, 21.8, 29.06], [3.78, 39.17, 82.55, 142.5, 184.14], label="Spark RDD", ls='--', marker='s')
ax.plot([0.73, 7.26, 14.53, 21.8, 29.06], [7.10, 108.06, 204.5, 131.2, 551.8], label="DIABLO", ls='-.', marker='o')
ax.plot([0.73, 7.26, 14.53, 21.8, 29.06], [2.86, 13.05, 25.4, 27.6, 51.5], label="SQLGen", ls=':', marker='*')
ax.plot([0.73, 7.26, 14.53, 21.8, 29.06], [2.93, 12.55, 24.92, 29.8, 49.98], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(L) PageRank');
#plt.savefig('page-rank.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([1.53, 3.07, 4.60, 6.14, 7.68], [61.92, 124.5, 216.385, 298.47, 367.13], label="Spark RDD", ls='--', marker='s')
ax.plot([1.53, 3.07, 4.60, 6.14, 7.68], [57.51, 128.11, 209.4, 297.9, 464.02], label="DIABLO", ls='-.', marker='o')
ax.plot([1.53, 3.07, 4.60, 6.14, 7.68], [19.52, 34, 50.75, 67.86, 101.37], label="SQLGen", ls=':', marker='*')
ax.plot([1.53, 3.07, 4.60, 6.14, 7.68], [17.08, 35.32, 41.776, 64.8, 87.34], label="Spark SQL",  ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(K) Matrix Factorization',y=-.27);
plt.savefig('matrix-factorization.eps', bbox_inches='tight', pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([4.3, 8.61, 12.91, 17.21, 21.51], [1.42, 2.44, 4.36, 8, 9.425], label="Spark RDD", ls='--', marker='s')
ax.plot([4.3, 8.61, 12.91, 17.21, 21.51], [5.72, 11.87, 15.57, 27.3, 32.26], label="DIABLO", ls='-.', marker='o')
ax.plot([4.3, 8.61, 12.91, 17.21, 21.51], [3.8, 7.58, 8, 16.41, 19.03], label="SQLGen", ls=':', marker='*')
ax.plot([4.3, 8.61, 12.91, 17.21, 21.51], [4.16, 6.73, 8.03, 15.32, 15.36], label="Spark SQL",  ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(F) String Match',y=-.27);
plt.savefig('string-match.eps', bbox_inches='tight',  pad_inches=.1)

# %%
fig, ax = plt.subplots()
ax.plot([7.26, 14.53, 21.8, 29.06, 36.32], [40.2, 76.93, 126.4, 180.16, 292.43], label="Spark RDD", ls='--', marker='s')
ax.plot([7.26, 14.53, 21.8, 29.06, 36.32], [99.88, 206.02, 133.44, 478.9, 301.18], label="DIABLO", ls='-.', marker='o')
ax.plot([7.26, 14.53, 21.8, 29.06, 36.32], [18.23, 38.33, 21.2, 77.33, 21.25], label="SQLGen", ls=':', marker='*')
ax.plot([7.26, 14.53, 21.8, 29.06, 36.32], [13.63, 52.24, 44.63, 55.16, 97.67], label="Spark SQL", ls='-', marker='p')
ax.legend(loc=2); # upper left corner
ax.set_xlabel('Input Size (GB)')
ax.set_title('(L) PageRank',y=-.27);
plt.savefig('page-rank.eps', bbox_inches='tight', pad_inches=.1)
